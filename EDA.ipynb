# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Student Depression Dataset.csv')
data.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
data.shape
# Out:
# (27901, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
data.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %%
for col in data.columns:
    print(f"Column name {col}:\n {data[col].unique()}")
    print("="*35)
# Out:
# Column name id:
#  [     2      8     26 ... 140689 140690 140699]
# ...
# Column name Gender:
#  ['Male' 'Female']
# ...
# Column name Age:
#  [33. 24. 31. 28. 25. 29. 30. 27. 19. 20. 23. 18. 21. 22. 34. 32. 26. 39.
#  35. 42. 36. 58. 49. 38. 51. 44. 43. 46. 59. 54. 48. 56. 37. 41.]
# ...
# Column name City:
#  ['Visakhapatnam' 'Bangalore' 'Srinagar' 'Varanasi' 'Jaipur' 'Pune' 'Thane'
#  'Chennai' 'Nagpur' 'Nashik' 'Vadodara' 'Kalyan' 'Rajkot' 'Ahmedabad'
#  'Kolkata' 'Mumbai' 'Lucknow' 'Indore' 'Surat' 'Ludhiana' 'Bhopal'
#  'Meerut' 'Agra' 'Ghaziabad' 'Hyderabad' 'Vasai-Virar' 'Kanpur' 'Patna'
#  'Faridabad' 'Delhi' 'Saanvi' 'M.Tech' 'Bhavna' 'Less Delhi' 'City' '3.0'
#  'Less than 5 Kalyan' 'Mira' 'Harsha' 'Vaanya' 'Gaurav' 'Harsh' 'Reyansh'
#  'Kibara' 'Rashi' 'ME' 'M.Com' 'Nalyan' 'Mihir' 'Nalini' 'Nandini'
#  'Khaziabad']
# ...
# Column name Profession:
#  ['Student' 'Civil Engineer' 'Architect' 'UX/UI Designer'
#  'Digital Marketer' 'Content Writer' 'Educational Consultant' 'Teacher'
# ...

# %%
for col in data.columns:
    print(f"Column name {col}:\n {data[col].value_counts()}")
    print("="*35)
# Out:
# Column name id:
#  id
# 2         1
# 94192     1
# 94236     1
# 94235     1
# 94234     1
#          ..
# 46880     1
# 46877     1
# 46873     1
# 46872     1
# 140699    1
# Name: count, Length: 27901, dtype: int64
# ...
# Column name Gender:
#  Gender
# Male      15547
# Female    12354
# Name: count, dtype: int64
# ...
# Column name Age:
#  Age
# 24.0    2258
# 20.0    2237
# 28.0    2133
# 29.0    1950
# 33.0    1893
# 25.0    1784
# 21.0    1726
# 23.0    1645
# 18.0    1587
# 19.0    1560
# 34.0    1468
# 27.0    1462
# 31.0    1427
# 32.0    1262
# 22.0    1160
# 26.0    1155
# 30.0    1145
# 35.0      10
# 38.0       8
# 36.0       7
# 42.0       4
# 48.0       3
# 39.0       3
# 43.0       2
# 46.0       2
# 37.0       2
# 49.0       1
# 51.0       1
# 44.0       1
# 59.0       1
# 54.0       1
# 58.0       1
# 56.0       1
# 41.0       1
# Name: count, dtype: int64
# ...
# Column name City:
#  City
# Kalyan                1570
# Srinagar              1372
# Hyderabad             1340
# ...

# %% [markdown]
# ## Data Cleaning and Removing unnecessary columns

# %%
for col in data.columns:
    if data[col].dtype == 'object':
        data[col] = data[col].fillna('Unknown')

    else:
        data[col] = data[col].fillna(data[col].median())

# %%
data = data.drop(columns=['id', 'Work Pressure'], axis=1)

# %%
numeric_cols = data.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = data.select_dtypes(include=['object']).columns.tolist()

# %% [markdown]
# ## EDA and Visualization

# %%
data
# Out:
#        Gender   Age           City Profession  Academic Pressure  CGPA  \
# 0        Male  33.0  Visakhapatnam    Student                5.0  8.97
# 1      Female  24.0      Bangalore    Student                2.0  5.90
# 2        Male  31.0       Srinagar    Student                3.0  7.03
# 3      Female  28.0       Varanasi    Student                3.0  5.59
# 4      Female  25.0         Jaipur    Student                4.0  8.13
# ...       ...   ...            ...        ...                ...   ...
# 27896  Female  27.0          Surat    Student                5.0  5.75
# 27897    Male  27.0       Ludhiana    Student                2.0  9.40
# 27898    Male  31.0      Faridabad    Student                3.0  6.61
# 27899  Female  18.0       Ludhiana    Student                5.0  6.88
# 27900    Male  27.0          Patna    Student                4.0  9.24
#
#        Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# ...

# %%
data['Sleep Duration'].unique()
# Out:
# array(['5-6 hours', 'Less than 5 hours', '7-8 hours', 'More than 8 hours',
#        'Others'], dtype=object)

# %%
order = ["Less than 5 hours", "5-6 hours", "7-8 hours", "More than 8 hours", "Others"]

plt.figure(figsize=(7, 6))
sns.violinplot(data=data, x='Sleep Duration',
               y='Academic Pressure', hue='Gender',
               split=True, order=order,
               palette='muted')
# Out:
# <Axes: xlabel='Sleep Duration', ylabel='Academic Pressure'>

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=data, 
            x='Dietary Habits', 
            y='Job Satisfaction', 
            hue='Gender',
            errorbar=None, 
            palette='pastel')
plt.title("Average Job Satisfaction by Diet")
plt.show()

# %%
plt.figure(figsize=(7, 6))
sns.set_theme(style="ticks", palette="pastel")
sns.boxplot(data=data, x='Gender',
             y='Academic Pressure',
             hue='Study Satisfaction',
             palette=["m", "g"])
# Out:
# <Axes: xlabel='Gender', ylabel='Academic Pressure'>

# %%
for col in numeric_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(data[col], kde=True, bins=20, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.show()

    plt.figure(figsize=(6,4))
    sns.boxplot(x=data[col], color='lightgreen')
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
for col in categorical_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(x=data[col], palette='Set2')
    plt.title(f'Countplot of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
# 6. Correlation Matrix (Numeric Only)
# ----------------------------
plt.figure(figsize=(10,8))
sns.heatmap(data[numeric_cols + ['Depression']].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix (Numeric Features)')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x=data['Depression'], palette='Set1')
plt.title('Distribution of Depression (Target)')
plt.show()

# %% [markdown]
# ## Summary
#
# ### Dataset Structure and Quality
# The dataset looks clean and easy to work with. Most columns have complete data, and only a few small gaps appear here and there. The numeric values mostly stay within normal ranges, with only a couple of points standing out as outliers, which is expected in real data.
#
# ### Target Variable Distribution
# The “Depression” column isn’t perfectly balanced. One category appears more often than the other. Because of this, splitting the data carefully or using balancing methods might help later when building models.
#
# ### Numerical Feature Insights
# The graphs show that many numeric columns don’t follow a perfect normal shape. Some have skewness, and a few contain mild outliers. The correlation heatmap didn’t show any very strong relationships between numeric features, so there’s no multicollinearity issue. However, a few moderate correlations may still help the model.
#
# ### Categorical Feature Patterns
# The countplots show that the number of responses for each category is not evenly spread, which is common in surveys. When comparing these features with the depression levels, some categories clearly differ between the two groups. This means certain lifestyle or academic factors might be related to depression and could help the model learn better.
#
# ### Relationship Between Features and Target
#
# 1. Numeric vs Depression: Some numerical features show different distributions when split by depression level. This suggests they might influence the prediction.
#
# 2. Categorical vs Depression: A few categorical features also show clear differences between depression categories, meaning they may carry useful signals.
#
# ### Missing Values Visualization
# The heatmap shows that missing values are very few and scattered. There’s no major pattern of missingness, and no column appears to have serious data gaps.
#
# ### Overall Assessment
# Overall, the dataset is fit for modeling. Both numerical and categorical features seem helpful, and no single variable dominates the dataset. The model will likely learn from a combination of several small patterns. The slight imbalance in the depression column should be handled during model training.
